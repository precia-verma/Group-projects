# %% [markdown]
# ---
# title: 📚 Array Homework
# comments: true
# layout: base
# permalink: /coders/arrayhomework
# description: 📚 Array Homework
# author: The Coders!
# ---

# %%
# %%html
#
# <html>
#
# <body>
#   <h2>Homework Output</h2>
#   <div id="output"></div>
#
#   <script>
#     document.getElementById("output").innerText = ""; // Clear output
#     (() => {
#
#         let numbers = [1, 2, 3, 4];
#         console.log(numbers);
#         document.getElementById("output").innerText += numbers;
#
#
#     })();
#   </script>
# </body>
# </html>
# Out:
# <html>
#
# <body>
#   <h2>Homework Output</h2>
#   <div id="output"></div>
#
#   <script>
#     document.getElementById("output").innerText = ""; // Clear output
#     (() => {
#
#         numbers = [1, 2, 3, 4];
#         console.log(numbers);
#         document.getElementById("output").innerText += numbers;
#
#
#     })();
#   </script>
# </body>
# </html>
