# %%
# --- Page Metadata ---
metadata = {
    "layout": "base",
    "title": "Homework: Calculator Lesson",
    "search_exclude": True
}

print("Page Metadata:")
for k, v in metadata.items():
    print(f"\033[1m{k}\033[0m: {v}")

# --- Decorative Divider ---
print("\n" + "="*50 + "\n")

# %% [markdown]
# ## Homework for Calculator Lesson
# ##### At the end of this page you will be provided with a link to a short quiz, a reflection of what you have learned about booleans in the quick lesson. But first, here are some key concepts to remember for your quiz.

# %% [markdown]
# ## Key Concepts:
#
# ##### •  A boolean is a data type that has only two possible values : True and False
#
# ##### •  Booleans let programs make decisions based on conditions.
#
# ##### •  Common Uses of a Boolean include: determining if a number is positive, checking if a file exists, and controlling program flow with if/else.
#
# #### Different types of Booleans :
#
# ##### •  Direct assingment: is_sunny = True
#
# ##### •  Comparisons: is_adult = 18 >= 18 → evaluates to True
#
#
# #### Examples of Boolean Operators :
#
#
# ##### • and - True if both conditions are True
# ##### • or -  True if at least one condition is True
# ##### • not - Flips True to False (and vice versa)
#
#
# ### Now that you have had a quick review, here is a link to the google forms quiz :
#
# <a href="https://forms.gle/UAti1DExXeJBdERA7" target="_blank">
#   <button style="padding:10px 20px; font-size:16px; background-color:#2196F3; color:white; border:none; border-radius:6px; cursor:pointer;">
#     Go to the Form
#   </button>
# </a>
